# %% [markdown]
# # **Implementing Function in python**

# %%
def cake_baker(p,f,s):
  print("no of pieces=",p)
  print("flavour is=",f)
  print("size is=",s)
cake_baker("5","chocolate","2kg")
cake_baker("100","vanila","5kg")
# Out:
# no of pieces= 5
# flavour is= chocolate
# size is= 2kg
# no of pieces= 100
# flavour is= vanila
# size is= 5kg

# %% [markdown]
# # **Args**

# %%
def add(*args)
 sum=0
  for i in args
  sum+=i
 return sum
print(add(1,2,3))
# Out:
#   File "<ipython-input-8-0f0730feb563>", line 1
#     def add(*args)
#                   ^
# SyntaxError: expected ':'

# %% [markdown]
# # **Random Module**

# %%
import random

x=random.randint(1,15)
print(x)

a=random.random()
print(a)
# Out:
# 3
# 0.13789105485766262

# %% [markdown]
# # **Lottery Game**

# %%
import random

computer=random.randint(1,9)
userinput=int(input("enter the number between 1 and 9"))
print(computer)
print(userinput)

if computer>userinput:
 print("computer won")
elif computer==userinput:
 print("tie")
else:
  print("you won")
# Out:
# enter the number between 1 and 95
# 9
# 5
# computer won

# %% [markdown]
# # **Rock paper scissor**

# %%
import random

gamelist=['rock','paper','scissor']
comp=random.choice(gamelist)
user=input("enter the rock or paper or scissor")
print(comp)
print(user)
if(comp=="rock" and user=="paper"):
  print("computer won")
elif(comp=="paper" and user=="scissor"):
  print("you won")
elif(comp=="scissor" and user=="paper"):
  print("computer won")
else:
  print("tie")
# Out:
# enter the rock or paper or scissorrock
# scissor
# rock
# tie

# %% [markdown]
# # **Numpy-Numerical python**

# %%
import numpy as np

a=np.array([35,24,12,75,45])
print(type(a))
# Out:
# <class 'numpy.ndarray'>
