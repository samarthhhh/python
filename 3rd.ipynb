# %% [markdown]
# # **Bitwise Operators**

# %%
print(8 & 12)
print(0xF & 0xE)
print(8 | 12)
print(0xF | 0xE)
print(12^ 24)
print(0xF ^ 0xE)
# Out:
# 8
# 14
# 12
# 15
# 20
# 1

# %% [markdown]
# # **Identify And Membership Opearators**

# %%
x=["hubli","belgaum"]
y=["hubli","belgaum"]
z=x
print(z is x)
print(z is y)
# Out:
# True
# False
