# %% [markdown]
# # **tasks**

# %%
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt

x=np.array([])
y=np.array([])
for i in range(1,6):
  z=random.randint(1,100)
  t=random.randint(1,100)
  x=np.append(x,z)
  y=np.append(y,t)
print(x)
print(y)
x=x.reshape((-1,1))
# Out:
# [95. 45. 95. 84. 77.]
# [ 8. 25. 90. 37. 66.]

# %%
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red',marker='*')
print("MSE:",mse)
print("intercept:",SLR.intercept_)
print("slope:",SLR.coef_)
# Out:
# MSE: 797.668340405469
# intercept: 11.322489391796331
# slope: [0.42774635]

# %% [markdown]
# # **2.question**

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
df = pd.read_excel('/content/new.xlsx')
df = df.values

x = df[:, 0]

y = df[:, 1]
print("x :",x)

print("y :" ,y)

x=x.reshape(-1,1)
plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(x,y)
pred=SLR.predict(x)
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red',marker='*')
print("MSE:",mse)
print("intercept:",SLR.intercept_)
print("slope:",SLR.coef_)
# Out:
# x : [10 20 30 40 50]
# y : [12 24 36 48 60]
# MSE: 8.204153414298523e-30
# intercept: -7.105427357601002e-15
# slope: [1.2]
