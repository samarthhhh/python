# %% [markdown]
# # ***Assignment 2***

# %%
tuple=("Dharwad","haveri","chennai","dharwad")
print(tuple[0])
print(tuple[1])
print(tuple[2])
print(tuple[-2])
# Out:
# Dharwad
# haveri
# chennai
# chennai

# %%
x=("hubli","belgaum","blore")
print(type(x))
# Out:
# <class 'tuple'>

# %%
set1={"red","blue","black","red"}
print(set1)
set1.add('orange')
print(set1)
set2={"violet","yellow","purple"}
set1.update(set2)
print(set1)
# Out:
# {'black', 'blue', 'red'}
# {'orange', 'black', 'blue', 'red'}
# {'black', 'red', 'violet', 'purple', 'orange', 'blue', 'yellow'}

# %%
dict1={"name":"Varsha","Age":"18","Gender":"female"}
print(dict1)
print(type(dict1))
# Out:
# {'name': 'Varsha', 'Age': '18', 'Gender': 'female'}
# <class 'dict'>

# %%
x=24
y=12

sum=x+y
diff=x-y
prod=x*y
div=x/y
fdiv=x//y
mod=x%y
power=x**y

print(sum,diff,prod,div,fdiv,mod,power)
# Out:
# 36 12 288 2.0 2 0 36520347436056576
